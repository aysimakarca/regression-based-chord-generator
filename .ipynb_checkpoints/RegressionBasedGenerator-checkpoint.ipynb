# %% [markdown]
# ## Extracting chords from ChordPro files of The Beatles Songs.
#
# Data was collected from http://getsome.org/guitar/olga/chordpro/b/Beatles/

# %%
import re
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
uniqueChordNames = ["A","B", "C", "D", "E", "F", "G"]

# %%
def readChordProFile(chordProFile):
    with open(chordProFile, 'r') as file:
        print(chordProFile)
        content = file.read()
        return content

# %%
def extractChord(line):
    chord_pattern = r'\[([^\]]+)\]'
    finalChords = []
    lineChords = []
    if "[" in line:
        lineChords = re.findall(chord_pattern, line)
    for chord in lineChords:
        chord = chord.replace('H', 'B')
        chord = chord.replace('min', 'm')
        chord = chord.replace('maj', '')
        chord = chord.replace('sus', '')
        chord = chord.replace('dim', '')
        chord = chord.replace('(', '')
        chord = chord.replace('+', '')
        chord = chord.replace('?', '')
        chord = chord.split("/")[0]
        chord = chord.split("+")[0]
        if len(chord) > 3:
            print('Curring long chord ', chord)
            chord = chord[0:3]
        if chord[0:1] in uniqueChordNames:
            finalChords.append(chord)
    return finalChords

# %%
class Song:
    def __init__(self, chordProFile):
        self.chordProFile = chordProFile
        self.content = readChordProFile(chordProFile)
        self.chorus = self.getChorus()
        self.chords = self.getChords()
        self.title = self.getTitle()
        self.key = self.getKey()
        
    def getChords(self):
        chords = []
        
        for line in self.content.split("\n"):
            if "chorus}" in line.lower():
                chorus_chords = self.getChorus()
                chords.extend(chorus_chords)
                
            chords.extend(extractChord(line))
        print('Chord of the song: ' + self.chordProFile, chords)
        return chords
        
    def getChorus(self):
        pattern = r"{soc}(.*?){eoc}"
        match = re.search(pattern, self.content, re.DOTALL)
        chords = []
        if match:
            chorus = match.group(1).strip()
            chord_pattern = r"\[([^\]]*)\]"
            chords = re.findall(chord_pattern, chorus)
            print("Chords in chorus:", chords)
        else:
            print("Chorus section not found.")
        return chords
    
    def getTitle(self):
        pattern = r"\{title:\s*(.*?)\s*\}"
        match = re.search(pattern, self.content)
        title = ''
        if match:
            title = match.group(1)
            print("The title is:", title)
        else:
            print("Title information not found, using the file name.")
            title = os.path.splitext(os.path.basename(self.chordProFile))[0]
            print("The file name is being used as title:", title)
        return title
    
    def getKey(self):
        pattern = r"{key:\s*([A-G][#b]?)\s*}"
        match = re.search(pattern, self.content)
        key = ''
        if match:
            key = match.group(1)
            print("The key is:", key)
        else:
            print("Key information not found.")
        return key

# %%
def createChordDictFromChordProFiles(dataFolderPath):
    fileNames = os.listdir(dataFolderPath)
    chordsDict = {}
    longestChordLength = 0
    for file in fileNames:
        print(file)
        if '.DS_Store' in file:
            continue
        chordproFile = dataFolderPath + file
        song = Song(chordproFile)
        chordsDict[song.title] = song.chords
    return chordsDict

# %%
pathOfChordTxtFiles = './data/chordpro/'

songDict = createChordDictFromChordProFiles(pathOfChordTxtFiles)
print(songDict)
# Out:
# HelloGoodbye.chopro
# ./data/chordpro/HelloGoodbye.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro
# Chords in chorus: ['Hm', 'G', 'E7', 'A', 'A']
# Chord of the song: ./data/chordpro/Help.chopro ['Bm', 'G', 'E7', 'A', 'A', 'C#m', 'F#m', 'D', 'G', 'A', 'C#m', 'F#m', 'D', 'G', 'A', 'Bm', 'G', 'E7', 'A', 'A', 'A', 'C#m', 'F#m', 'D', 'G', 'A', 'C#m', 'F#m', 'D', 'G', 'A', 'Hm', 'G', 'E7', 'A', 'A', 'A', 'F#m', 'A', 'A6']
# Title information not found, using the file name.
# The file name is being used as title: Help
# Key information not found.
# ADayInALife.chopro
# ./data/chordpro/ADayInALife.chopro
# Chorus section not found.
# Curring long chord  F#m7
# Curring long chord  F#m7
# Curring long chord  F#m7
# Curring long chord  F#m7
# Chord of the song: ./data/chordpro/ADayInALife.chopro ['G', 'Bm', 'Em', 'Em7', 'C', 'C', 'G', 'Bm', 'Em', 'C', 'Em', 'Am', 'C7', 'G', 'Bm', 'Em', 'C', 'F', 'Em', 'E', 'C', 'F', 'Em', 'C7', 'G', 'Bm', 'Em', 'C', 'Em', 'Am', 'C7', 'G', 'Bm', 'Em', 'C', 'F', 'Em', 'E', 'C', 'G', 'Bm', 'Em', 'C', 'Em', 'Am', 'C7', 'G', 'Bm', 'Em', 'C', 'F', 'Em', 'E', 'C', 'Bm', 'G', 'G', 'E', 'E', 'D', 'E', 'F#m', 'E', 'F#m', 'E', 'D', 'E', 'F#m', 'E', 'F#m', 'C', 'G', 'D', 'A', 'C', 'G', 'D', 'A', 'G', 'Bm', 'Em', 'C', 'Em', 'Am', 'C7', 'G', 'Bm', 'Em', 'C', 'F', 'Em', 'E', 'C', 'Bm', 'G', 'G', 'E']
# The title is: A Day in a Life
# Key information not found.
# DontLetMeDown.chopro
# ./data/chordpro/DontLetMeDown.chopro
# Chorus section not found.
# Curring long chord  F#m7
# Curring long chord  F#m7
# Curring long chord  F#m7
# Chorus section not found.
# Chorus section not found.
# Chorus section not found.
# Chord of the song: ./data/chordpro/DontLetMeDown.chopro ['E', 'F#m', 'F#m', 'A7', 'E', 'F#m', 'F#m', 'A7', 'E4', 'E', 'E', 'F#m', 'F#m', 'E', 'E4', 'E', 'F#m', 'F#m', 'E', 'E4', 'E', 'B', 'B7', 'E', 'A', 'E']
# Title information not found, using the file name.
# The file name is being used as title: DontLetMeDown
# Key information not found.
# FromMeToYou.chopro
# ./data/chordpro/FromMeToYou.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/FromMeToYou.chopro ['G', 'Em', 'G', 'D7', 'C7', 'Em', 'C', 'D7', 'G', 'G', 'Em', 'G', 'D7', 'C7', 'Em', 'C', 'D7', 'G', 'Dm7', 'G7', 'C', 'Em7', 'A7', 'D7', 'D7', 'G', 'Em', 'G', 'D7', 'C7', 'Em', 'C', 'D7', 'G']
# The title is: From Me To You
# Key information not found.
# SoldierOfLove.chopro
# ./data/chordpro/SoldierOfLove.chopro
# Chords in chorus: ['Dm', 'F', 'Dm', 'F', 'Dm', 'Gm', 'F']
# Chord of the song: ./data/chordpro/SoldierOfLove.chopro ['F', 'Dm', 'F', 'Dm', 'F', 'F6', 'Dm', 'F', 'Dm', 'F', 'Dm', 'Gm', 'F', 'F', 'A7', 'Bb', 'C7', 'F', 'A7', 'Bb', 'C7', 'F', 'Dm', 'F', 'Dm', 'F']
# Title information not found, using the file name.
# The file name is being used as title: SoldierOfLove
# Key information not found.
# EleanorRigby.chopro
# ./data/chordpro/EleanorRigby.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/EleanorRigby.chopro ['Bb', 'Dm', 'Bb', 'Dm', 'Dm', 'Bb6', 'Dm', 'Dm', 'Bb6', 'Dm', 'Dm7', 'Dm6', 'Bb', 'Dm', 'Dm7', 'Dm6', 'Bb', 'Dm']
# The title is: Eleanor Rigby
# Key information not found.
# ChristmastimeIsHereAgain.chopro
# ./data/chordpro/ChristmastimeIsHereAgain.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/ChristmastimeIsHereAgain.chopro ['D', 'D7', 'G', 'D', 'A7', 'D', 'A7']
# Title information not found, using the file name.
# The file name is being used as title: ChristmastimeIsHereAgain
# Key information not found.
# WeCanWorkItOut.chopro
# ./data/chordpro/WeCanWorkItOut.chopro
# Chorus section not found.
# Chorus section not found.
# Chorus section not found.
# Chord of the song: ./data/chordpro/WeCanWorkItOut.chopro ['G', 'C', 'G', 'G', 'C', 'F', 'G', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'C', 'G', 'C', 'D', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'C', 'G', 'C', 'D', 'Em', 'Am', 'B', 'B', 'Em', 'D', 'C', 'D', 'Em', 'Am', 'B', 'B', 'Em', 'D', 'C', 'D', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'C', 'G', 'C', 'D']
# Title information not found, using the file name.
# The file name is being used as title: WeCanWorkItOut
# Key information not found.
# WithALittleHelpFromMyFriends.chopro
# ./data/chordpro/WithALittleHelpFromMyFriends.chopro
# Chords in chorus: ['C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F']
# Chords in chorus: ['C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F']
# Chords in chorus: ['C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F']
# Chords in chorus: ['C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F']
# Chord of the song: ./data/chordpro/WithALittleHelpFromMyFriends.chopro ['C', 'Dm', 'G7', 'G7', 'C', 'Dm', 'G7', 'G7', 'C', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F']
# Title information not found, using the file name.
# The file name is being used as title: WithALittleHelpFromMyFriends
# Key information not found.
# .DS_Store
# AllTogetherNow.chopro
# ./data/chordpro/AllTogetherNow.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/AllTogetherNow.chopro ['F', 'C7', 'F', 'C7', 'F', 'F', 'C7', 'F', 'C7', 'F', 'F', 'Bb', 'F', 'Bb', 'C7', 'F', 'C7', 'F']
# The title is: All Together Now
# Key information not found.
# LetItBe.2.chopro
# ./data/chordpro/LetItBe.2.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro
# Chord of the song: ./data/chordpro/MaxwellsSilverHammer.chopro ['D', 'B7', 'Em', 'A7', 'D', 'A', 'D', 'B7', 'Em', 'A7', 'D', 'A', 'E7', 'A7', 'D', 'E7', 'A7', 'Em', 'A7', 'D', 'D', 'E7', 'A7', 'Em', 'A7', 'D', 'D', 'E7', 'A7', 'Em', 'A7', 'D']
# The title is: Maxwell's Silver Hammer
# Key information not found.
# HereThereAndEverywhere.2.chopro
# ./data/chordpro/HereThereAndEverywhere.2.chopro
# Chorus section not found.
# Curring long chord  F#m7
# Curring long chord  F#m7
# Curring long chord  F#m7
# Curring long chord  F#m7
# Curring long chord  F#m7
# Curring long chord  F#m7
# Chord of the song: ./data/chordpro/HereThereAndEverywhere.2.chopro ['G', 'Bm', 'Bb', 'Am', 'D7', 'G', 'Am7', 'Bm7', 'C', 'G', 'Am7', 'Bm7', 'C', 'F#m', 'B7', 'F#m', 'B7', 'Em', 'Am', 'Am7', 'D7', 'G', 'Am7', 'Bm7', 'C', 'G', 'Am7', 'Bm7', 'C', 'F#m', 'B7', 'F#m', 'B7', 'Em', 'Am', 'Am7', 'D7', 'F7', 'Bb', 'Gm', 'Cm', 'D7', 'Gm', 'Cm', 'D7', 'G', 'Am7', 'Bm7', 'C', 'G', 'Am7', 'Bm7', 'C', 'F#m', 'B7', 'F#m', 'B7', 'Em', 'Am', 'Am7', 'D7', 'G', 'Am7', 'Bm7', 'C', 'G', 'Am7', 'Bm7', 'C', 'G']
# The title is: Here There and Everywhere
# Key information not found.
# TwistAndShout.chopro
# ./data/chordpro/TwistAndShout.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/TwistAndShout.chopro []
# Title information not found, using the file name.
# The file name is being used as title: TwistAndShout
# Key information not found.
# GoodDaySunshine.chopro
# ./data/chordpro/GoodDaySunshine.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/GoodDaySunshine.chopro ['G', 'D', 'G', 'D', 'C7', 'F', 'Dm7', 'G7', 'C7', 'F', 'C7', 'F', 'Dm7', 'G7', 'C7', 'F', 'G', 'D', 'G', 'D', 'C7', 'G', 'D', 'G', 'D', 'G', 'D7', 'G', 'D7', 'G', 'D7']
# The title is: Good Day Sunshine
# Key information not found.
# ItsOnlyLove.chopro
# ./data/chordpro/ItsOnlyLove.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/ItsOnlyLove.chopro ['C', 'Em', 'Bb', 'F', 'G', 'G7', 'G', 'G', 'F', 'G', 'C', 'Am', 'Bb', 'G', 'C', 'Am', 'Bb', 'G', 'F', 'G', 'F', 'G', 'F', 'G', 'C', 'Am', 'C', 'Am']
# Title information not found, using the file name.
# The file name is being used as title: ItsOnlyLove
# Key information not found.
# SomeOtherGuy.chopro
# ./data/chordpro/SomeOtherGuy.chopro
# Chorus section not found.
# Curring long chord  D7add9
# Chord of the song: ./data/chordpro/SomeOtherGuy.chopro ['A', 'C', 'D', 'G', 'D', 'A', 'D', 'D', 'G7', 'D', 'A7', 'D9', 'D', 'D7', 'D9', 'D', 'A7', 'C', 'D', 'D7a']
# Title information not found, using the file name.
# The file name is being used as title: SomeOtherGuy
# Key information not found.
# Yesterday.chopro
# ./data/chordpro/Yesterday.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro
# Chorus section not found.
# Chorus section not found.
# Chord of the song: ./data/chordpro/EightDaysAWeek.2.chopro ['C', 'D7', 'F', 'C', 'D7', 'F', 'C', 'Am', 'F', 'Am', 'D7', 'C', 'D7', 'F', 'C', 'C', 'D7', 'F', 'C', 'D7', 'F', 'C', 'Am', 'F', 'Am', 'D7', 'C', 'D7', 'F', 'C', 'G', 'Am', 'D7', 'F', 'G7', 'C', 'D7', 'F', 'C', 'D7', 'F', 'C', 'Am', 'F', 'Am', 'D7', 'C', 'D7', 'F', 'C']
# The title is: Eight Days A Week
# Key information not found.
# CantBuyMeLove.chopro
# ./data/chordpro/CantBuyMeLove.chopro
# Chords in chorus: ['G#m', 'C#m', 'A7', 'E', 'G#m', 'C#m', 'F#m7', 'B7']
# Curring long chord  F#m7
# Curring long chord  F#m7
# Chord of the song: ./data/chordpro/CantBuyMeLove.chopro ['G#m', 'C#m', 'G#m', 'C#m', 'F#m', 'B7', 'E', 'E7', 'A7', 'E', 'B7', 'A7', 'B7', 'A7', 'E', 'G#m', 'C#m', 'A7', 'E', 'G#m', 'C#m', 'F#m', 'B7']
# The title is: Can't Buy Me Love
# Key information not found.
# StrawberryFieldsForever.chopro
# ./data/chordpro/StrawberryFieldsForever.chopro
# Chorus section not found.
# Curring long chord  E7-5
# Chord of the song: ./data/chordpro/StrawberryFieldsForever.chopro ['G', 'Dm7', 'E7-', 'C', 'D', 'E', 'Am7', 'D', 'G', 'D', 'D7', 'B7', 'Em', 'C', 'Am7', 'D7', 'G', 'Em', 'Am7', 'D7', 'C', 'G', 'C']
# The title is: Strawberry Fields Forever
# Key information not found.
# Clarabella.chopro
# ./data/chordpro/Clarabella.chopro
# Chords in chorus: ['C7', 'G', 'D7', 'C7', 'G']
# Chord of the song: ./data/chordpro/Clarabella.chopro ['G', 'G', 'G7', 'C7', 'G', 'D7', 'C7', 'G', 'G', 'G', 'G7', 'C7', 'G', 'D7', 'C7', 'G', 'D7', 'G', 'G7', 'C', 'G', 'D', 'C7', 'G', 'D7', 'G', 'G', 'G7', 'G9']
# Title information not found, using the file name.
# The file name is being used as title: Clarabella
# Key information not found.
# IWantToHoldYourHand.chopro
# ./data/chordpro/IWantToHoldYourHand.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/IWantToHoldYourHand.chopro ['C', 'G', 'Am', 'Em', 'C', 'G', 'Am', 'E', 'F', 'G7', 'C', 'Am', 'F', 'G7', 'C', 'Dm', 'C', 'F', 'Dm', 'Dm', 'C', 'F', 'G', 'F', 'G', 'F', 'G']
# The title is: I Want To Hold Your Hand
# Key information not found.
# BabysInBlack.chopro
# ./data/chordpro/BabysInBlack.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro
# Chorus section not found.
# Chorus section not found.
# Chord of the song: ./data/chordpro/EightDaysAWeek.chopro ['Bb', 'C7', 'Eb', 'Bb', 'C7', 'Eb', 'Bb', 'Gm', 'Eb', 'Gm', 'Eb', 'Bb', 'C7', 'Eb', 'Bb', 'Bb', 'C7', 'Eb', 'Bb', 'C7', 'Eb', 'Bb', 'Gm', 'Eb', 'Gm', 'Eb', 'Bb', 'C7', 'Eb', 'Bb', 'F', 'Gm', 'C7', 'Eb', 'F7', 'Bb', 'C7', 'Eb', 'Bb', 'C7', 'Eb', 'Bb', 'Gm', 'Eb', 'Gm', 'Eb', 'Bb', 'C7', 'Eb', 'Bb']
# The title is: Eight Days A Week
# Key information not found.
# ISawHerStandingThere.chopro
# ./data/chordpro/ISawHerStandingThere.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/ISawHerStandingThere.chopro ['A', 'D7', 'A', 'E7', 'A', 'A7', 'D', 'F', 'A', 'E7', 'A', 'A', 'D7', 'A', 'E7', 'A', 'A7', 'D', 'F', 'A', 'E7', 'A', 'D7', 'E', 'A', 'D7', 'A', 'E7', 'A', 'A7', 'D', 'F', 'A', 'E7', 'A', 'D7', 'E', 'A', 'D7', 'A', 'E7', 'A', 'A7', 'D', 'F', 'A', 'E7', 'A', 'A', 'E7', 'A', 'A', 'E7', 'A']
# Title information not found, using the file name.
# The file name is being used as title: ISawHerStandingThere
# Key information not found.
# ComeTogether.chopro
# ./data/chordpro/ComeTogether.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/ComeTogether.chopro ['Dm', 'Dm', 'A7', 'G7', 'Dm', 'Dm', 'A7', 'G7', 'Bm', 'G', 'Dm', 'Dm', 'A7', 'G7', 'Bm', 'G', 'Dm', 'Dm', 'A7', 'G7', 'Bm']
# Title information not found, using the file name.
# The file name is being used as title: ComeTogether
# Key information not found.
# CryBabyCry.chopro
# ./data/chordpro/CryBabyCry.chopro
# Chords in chorus: ['G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G']
# Chords in chorus: ['G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G']
# Chords in chorus: ['G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G']
# Chords in chorus: ['G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G']
# Chord of the song: ./data/chordpro/CryBabyCry.chopro ['G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'Em', 'Em7', 'Em7', 'Em6', 'C7', 'G', 'Em', 'Em7', 'Em7', 'Em6', 'C7', 'G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G', 'G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G', 'G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G', 'G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'G', 'G', 'Am', 'F', 'G', 'Am', 'F', 'G', 'Em7', 'A7', 'F', 'Em']
# The title is: Cry Baby Cry
# Key information not found.
# PleasePleaseMe.chopro
# ./data/chordpro/PleasePleaseMe.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/PleasePleaseMe.chopro ['C', 'F', 'C', 'F', 'C', 'F', 'Dm', 'Am', 'F', 'C', 'F', 'G', 'C', 'F', 'C', 'F', 'C', 'F', 'Dm', 'Am', 'F', 'C', 'F', 'G', 'C', 'F', 'G7', 'C', 'F', 'C', 'F', 'G7', 'C', 'F', 'G', 'C', 'F', 'C', 'F', 'C', 'F', 'Dm', 'Am', 'F', 'C', 'F', 'G', 'C', 'F', 'G', 'C', 'F', 'G', 'C', 'Eb', 'D', 'G7', 'C']
# Title information not found, using the file name.
# The file name is being used as title: PleasePleaseMe
# Key information not found.
# HideYourLoveAway.chopro
# ./data/chordpro/HideYourLoveAway.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro
# Chorus section not found.
# Chorus section not found.
# Chord of the song: ./data/chordpro/IFeelFine.chopro ['D', 'C', 'G', 'G', 'D', 'C7', 'G', 'G', 'D', 'C7', 'G', 'G', 'Bm', 'C', 'D7', 'G', 'Bm', 'C7', 'D7', 'G', 'D', 'D7', 'C7', 'G', 'D7', 'C7', 'G']
# The title is: I Feel Fine
# Key information not found.
# AShotOfRythmAndBlues.chopro
# ./data/chordpro/AShotOfRythmAndBlues.chopro
# Chords in chorus: ['G7', 'D', 'G7', 'A7']
# Chord of the song: ./data/chordpro/AShotOfRythmAndBlues.chopro ['D', 'A', 'D', 'G7', 'D', 'A7', 'G7', 'A7', 'G7', 'G7', 'D', 'G7', 'A7', 'D', 'G7', 'D', 'G7', 'A7', 'D', 'G7', 'D', 'G7', 'A7', 'A', 'D', 'A', 'D', 'A', 'D', 'A', 'D', 'A6']
# Title information not found, using the file name.
# The file name is being used as title: AShotOfRythmAndBlues
# Key information not found.
# ThatsAlrightMama.chopro
# ./data/chordpro/ThatsAlrightMama.chopro
# Chorus section not found.
# Curring long chord  A7add9
# Chord of the song: ./data/chordpro/ThatsAlrightMama.chopro ['A', 'A7', 'D7', 'E7', 'A', 'A', 'D7', 'E7', 'A', 'E7', 'A', 'A7a']
# Title information not found, using the file name.
# The file name is being used as title: ThatsAlrightMama
# Key information not found.
# LucyInTheSkyWithDiamonds.chopro
# ./data/chordpro/LucyInTheSkyWithDiamonds.chopro
# Chorus section not found.
# Chorus section not found.
# Chorus section not found.
# Chord of the song: ./data/chordpro/LucyInTheSkyWithDiamonds.chopro ['A', 'A7', 'D', 'D', 'A', 'A7', 'D', 'D', 'G', 'A', 'A7', 'D', 'D', 'A', 'A7', 'D', 'Dm', 'C', 'Bb', 'C', 'F', 'Bb', 'C', 'G', 'D', 'G', 'C', 'D', 'G', 'C', 'D', 'G', 'C', 'D', 'D', 'A']
# The title is: Lucy In The Sky With Diamonds
# Key information not found.
# ObLaDiObLaDa.chopro
# ./data/chordpro/ObLaDiObLaDa.chopro
# Chorus section not found.
# Chorus section not found.
# Chorus section not found.
# Chorus section not found.
# Chorus section not found.
# Chord of the song: ./data/chordpro/ObLaDiObLaDa.chopro ['G', 'D7', 'G', 'G7', 'C', 'G', 'D7', 'G', 'G', 'Bm', 'Em', 'G', 'D7', 'G', 'G', 'D7', 'G', 'G7', 'C', 'G', 'D7', 'G', 'C', 'G', 'C', 'G', 'D7', 'G', 'D7', 'G', 'G7', 'C', 'G', 'D7', 'G']
# Title information not found, using the file name.
# The file name is being used as title: ObLaDiObLaDa
# Key information not found.
# Michelle.chopro
# ./data/chordpro/Michelle.chopro
# Chords in chorus: ['B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#']
# Chords in chorus: ['B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#']
# Chords in chorus: ['B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#']
# Chord of the song: ./data/chordpro/Michelle.chopro ['B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'Bm', 'D7', 'G', 'F#7', 'Bm', 'F#7', 'Bm', 'F#7', 'Bm', 'Em', 'Bm', 'Em', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'B', 'Em', 'A', 'G#0', 'F#', 'G#0', 'F#', 'Bm', 'Em', 'F#', 'Bm', 'F#7', 'B']
# The title is: Michelle
# Key information not found.
# HeyJude.chopro
# ./data/chordpro/HeyJude.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/HeyJude.chopro ['F', 'C', 'C7', 'C7', 'F', 'Bb', 'F', 'C7', 'F', 'F', 'C', 'C7', 'C7', 'F', 'Bb', 'F', 'C7', 'F', 'F7', 'Bb', 'Gm7', 'C7', 'F', 'F7', 'C7', 'F', 'C', 'C7', 'C7', 'F', 'Bb', 'F', 'C7', 'F', 'F7', 'Bb', 'Gm7', 'C7', 'F', 'F7', 'C7', 'F', 'C', 'C7', 'C7', 'F', 'Bb', 'F', 'C7', 'F']
# The title is: Hey Jude
# Key information not found.
# TicketToRide.chopro
# ./data/chordpro/TicketToRide.chopro
# Chorus section not found.
# Curring long chord  G6#11
# Chorus section not found.
# Chord of the song: ./data/chordpro/TicketToRide.chopro ['A', 'Bm', 'E7', 'F#m', 'D7', 'F#m', 'G7', 'G6', 'G6#', 'F#m', 'E7', 'A', 'D7', 'E7', 'D7', 'E7']
# Title information not found, using the file name.
# The file name is being used as title: TicketToRide
# Key information not found.
# AndILoveHer.chopro
# ./data/chordpro/AndILoveHer.chopro
# Chorus section not found.
# Chord of the song: ./data/chordpro/AndILoveHer.chopro ['Em', 'Bm', 'Em', 'Bm', 'Em', 'Bm', 'G', 'A', 'D', 'Em', 'Bm', 'Em', 'Bm', 'Em', 'Bm', 'G', 'A', 'D', 'Bm', 'D', 'Bm', 'A', 'Bm', 'A', 'AD', 'Em', 'Bm', 'Em', 'Bm', 'Em', 'Bm', 'G', 'A', 'D']
# Title information not found, using the file name.
# The file name is being used as title: AndILoveHer
# Key information not found.
# KeepYourHandsOffMyBaby.chopro
# ./data/chordpro/KeepYourHandsOffMyBaby.chopro
# Chords in chorus: ['G', 'Em', 'C', 'D7', 'G', 'Em', 'C', 'D7', 'G', 'C', 'G']
# Chord of the song: ./data/chordpro/KeepYourHandsOffMyBaby.chopro ['D7', 'G', 'D7', 'G', 'G', 'Em', 'C', 'D7', 'G', 'Em', 'C', 'D7', 'G', 'C', 'G', 'Em', 'G', 'Em', 'C', 'D7', 'G', 'C', 'G', 'G7']
# Title information not found, using the file name.
# The file name is being used as title: KeepYourHandsOffMyBaby
# Key information not found.
# ImSoTired.chopro
# ./data/chordpro/ImSoTired.chopro
# Chorus section not found.
E'], 'From Me To You': ['G', 'Em', 'G', 'D7', 'C7', 'Em', 'C', 'D7', 'G', 'G', 'Em', 'G', 'D7', 'C7', 'Em', 'C', 'D7', 'G', 'Dm7', 'G7', 'C', 'Em7', 'A7', 'D7', 'D7', 'G', 'Em', 'G', 'D7', 'C7', 'Em', 'C', 'D7', 'G'], 'SoldierOfLove': ['F', 'Dm', 'F', 'Dm', 'F', 'F6', 'Dm', 'F', 'Dm', 'F', 'Dm', 'Gm', 'F', 'F', 'A7', 'Bb', 'C7', 'F', 'A7', 'Bb', 'C7', 'F', 'Dm', 'F', 'Dm', 'F'], 'Eleanor Rigby': ['Bb', 'Dm', 'Bb', 'Dm', 'Dm', 'Bb6', 'Dm', 'Dm', 'Bb6', 'Dm', 'Dm7', 'Dm6', 'Bb', 'Dm', 'Dm7', 'Dm6', 'Bb', 'Dm'], 'ChristmastimeIsHereAgain': ['D', 'D7', 'G', 'D', 'A7', 'D', 'A7'], 'WeCanWorkItOut': ['G', 'C', 'G', 'G', 'C', 'F', 'G', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'C', 'G', 'C', 'D', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'C', 'G', 'C', 'D', 'Em', 'Am', 'B', 'B', 'Em', 'D', 'C', 'D', 'Em', 'Am', 'B', 'B', 'Em', 'D', 'C', 'D', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'G', 'C', 'G', 'G', 'C', 'F', 'G', 'C', 'G', 'C', 'D'], 'WithALittleHelpFromMyFriends': ['C', 'Dm', 'G7', 'G7', 'C', 'Dm', 'G7', 'G7', 'C', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb', 'F', 'Am7', 'D7', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'Am7', 'D7', 'C', 'Bb' ...

# %% [markdown]
# ### Map the string chord names to integer values

# %%
distinctChordNames = list(sorted({ele for val in songDict.values() for ele in val}))
print(distinctChordNames)
print(len(distinctChordNames))
# Out:
# ['A', 'A6', 'A7', 'A7a', 'A9', 'AD', 'Ab', 'Ab7', 'Am', 'Am6', 'Am7', 'B', 'B7', 'Bb', 'Bb6', 'Bbm', 'Bdim', 'Bm', 'Bm7', 'C', 'C#7', 'C#m', 'C+', 'C7', 'C74', 'C9', 'Cm', 'Cm7', 'D', 'D#', 'D4', 'D7', 'D7a', 'D9', 'Dm', 'Dm6', 'Dm7', 'E', 'E4', 'E6', 'E6a', 'E7', 'E7-', 'E7.', 'Eb', 'Eb6', 'Eb7', 'Em', 'Em6', 'Em7', 'F', 'F#', 'F#7', 'F#m', 'F6', 'F7', 'F7V', 'Fm', 'G', 'G#', 'G#0', 'G#7', 'G#m', 'G6', 'G6#', 'G6a', 'G7', 'G9', 'Gm', 'Gm6', 'Gm7', 'Hm']
# 72

# %%
def mapChordNamesToIndexes(chords):
    indexArr = []
    for i, chord in enumerate(chords):
        indexArr.append(distinctChordNames.index(chord))
    return indexArr

# %% [markdown]
# ### Create feature arrays

# %%
def getFeatureAndTargetArrForEachWindow(chords, windowLength, hopSize, index):
    featureArray = chords[index: index + windowLength]
    targetArray = chords[index + windowLength: index + windowLength + 1]
    return featureArray, targetArray

# %%
def getFeaturesAndTargetsByWindowAndHop(chordsDictionary, windowSize, hopSize):
    features = np.empty((0, windowSize), dtype=np.ndarray)
    targets = np.empty((0, 1), dtype=np.ndarray)
    for song in chordsDictionary:
        chordArray = chordsDictionary[song]
        if len(chordArray) < windowSize + 1:
            print('Chords are shorter than number of targets so skipping the song: ' + song)
            continue
        indexProcessed = 0
        while len(chordArray) - indexProcessed > windowSize + 1:
            featureArr, targetArray = getFeatureAndTargetArrForEachWindow(chordArray, windowSize, hopSize, indexProcessed)
            #features.extend(featureArr)
            featureArr = np.array(featureArr).reshape(1, len(featureArr))
            features = np.append(features, featureArr, axis=0)
            targetArray = np.array(targetArray).reshape(1, len(targetArray))
            targets = np.append(targets, targetArray, axis=0)
            #targets.extend(targetArr)
            indexProcessed = indexProcessed + hopSize

    features = np.array(features)
    targets = np.array(targets)
    print(features.shape)
    print(targets.shape)
    print('Slicing the song chords is done!')
    return features, targets

# %%
def fillChordArraysUntilDesiredLength(chordArr, desiredLength):
    finalArr = np.zeros(desiredLength, dtype=int)
    chordLength = len(chordArr)
    if chordLength < desiredLength:
        print('Chords are shorter than number of targets so repeating the chords: ' + song)
        quotient, remainder = divmod(desiredLength, chordLength) 
        print(str(chordLength) + " quotient " + str(quotient) + " remainder " + str(remainder))
        for step in range(quotient):
            finalArr[step*chordLength:(step+1)*chordLength] = chordArr
        finalArr[chordLength*quotient: desiredLength] = chordArr[0:remainder]
        print(len(finalArr))
    elif chordLength > desiredLength:
        finalArr = chordArr[0: desiredLength]
    else:
        finalArr = chordArr
    print(len(finalArr))
    print(finalArr)
    return finalArr

# %%
def getFeaturesAndTargetsOfFlatSong(chordsDictionary, desiredFeatureLength):
    features = np.zeros((len(chordsDictionary),desiredFeatureLength), dtype=int)
    targets = np.zeros((len(chordsDictionary),1), dtype=int)
    for i, song in enumerate(chordsDictionary):
        chordArray = chordsDictionary[song] 
        finalChords = fillChordArraysUntilDesiredLength(chordArray, desiredFeatureLength+1)
        features[i:] = finalChords[0:desiredFeatureLength]
        targets[i:] = finalChords[desiredFeatureLength:desiredFeatureLength+1]
    print(features.shape)
    print(targets.shape)
    print('Slicing the song chords is done!')
    return features, targets

# %%
windowSize = 16
hopSize = 8

featureLength = 50


pathOfChordTxtFiles = './data/chordsAsText/'
featureArr, targetArr = getFeaturesAndTargetsByWindowAndHop(finalChordDict, windowSize, hopSize)
#featureArr, targetArr = getFeaturesAndTargetsOfFlatSong(finalChordDict, featureLength)
print(featureArr.shape)
print(targetArr.shape)

print(featureArr)
#print(targetArr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 8
#       4 featureLength = 50
#       7 pathOfChordTxtFiles = './data/chordsAsText/'
# ----> 8 featureArr, targetArr = getFeaturesAndTargetsByWindowAndHop(finalChordDict, windowSize, hopSize)
#       9 #featureArr, targetArr = getFeaturesAndTargetsOfFlatSong(finalChordDict, featureLength)
#      10 print(featureArr.shape)
#
# Cell In[12], line 15, in getFeaturesAndTargetsByWindowAndHop(chordsDictionary, windowSize, hopSize)
#      13 featureArr = np.array(featureArr).reshape(1, len(featureArr))
#      14 features = np.append(features, featureArr, axis=0)
# ---> 15 targets = np.append(targets, np.array(targetArray, dtype=np.int32), axis=0)
#      16 #targets.extend(targetArr)
#      17 indexProcessed = indexProcessed + hopSize
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/ML-1/lib/python3.9/site-packages/numpy/lib/function_base.py:5444, in append(arr, values, axis)
#    5442     values = ravel(values)
#    5443     axis = arr.ndim-1
# -> 5444 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %% [markdown]
# ## Train SVMR model

# %%
from sklearn.model_selection import train_test_split
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn import svm
import sklearn
import pandas as pd

# %%
targets = pd.Series(targetArr.flatten())

# %%
#X_train, X_test, y_train, y_test = train_test_split(featureArr, targets, test_size=0.2, random_state=42)
feat_train, feat_test, tar_train, tar_test = train_test_split(featureArr, targets, test_size=0.3, random_state=4)

# %%
# Create SVR regression object
# C tolerand, epsilon the distance from the line
# The error term is instead handled in the constraints, where we set the absolute error less than or equal to a specified margin, called the maximum error, ϵ (epsilon).
# additional hyperparameter, C, that we can tune. As C increases, our tolerance for points outside of ϵ also increases. As C approaches 0, the tolerance approaches 0 and the equation collapses into the simplified (although sometimes infeasible) one.
regr = svm.SVR(C=1.0, epsilon=0.001, kernel='rbf')

# Train the model using the training sets
regr.fit(feat_train, tar_train)

# Make predictions using the testing set
tar_predict = regr.predict(feat_test)

# %%
#computing a set of performance metrics

#mean squared error (lower the better)
print('Mean squared error: %.4f'% sklearn.metrics.mean_squared_error(tar_test, tar_predict))

#mean absolute error (lower the better)
print('Mean absolute error: %.4f'% sklearn.metrics.mean_absolute_error(tar_test, tar_predict))

#maximum error (lower the better)
print('Max error squared error: %.4f'% sklearn.metrics.max_error(tar_test, tar_predict))

#median absolute error (lower the better)
print('Median absolute error: %.4f'% sklearn.metrics.median_absolute_error(tar_test, tar_predict))

#coefficient of determination (r2 score): 1 is perfect prediction (it can get arbitrary negative)
print('Coefficient of determination (R2 score): %.4f'% sklearn.metrics.r2_score(tar_test, tar_predict))

#explained variance score: 1 is perfect prediction (it can get arbitrary worse)
print('Explained variance score: %.4f'% sklearn.metrics.explained_variance_score(tar_test, tar_predict))

# %%
def accuracy(y_true, y_pred):
    return 1 - sklearn.metrics.mean_squared_error(y_true, y_pred)

# Calculate the accuracy of the model
acc = accuracy(tar_test, tar_predict)

# Plot the accuracy as a bar chart
plt.bar(["Accuracy"], [acc])
plt.title("Model Accuracy")
plt.show()
